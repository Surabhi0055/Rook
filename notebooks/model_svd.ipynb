# %%
# !pip uninstall numpy -y
# !pip install numpy==1.26.4
# !pip uninstall scikit-surprise -y
# !pip install scikit-surprise
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.3.29 requires langchain-core<2.0.0,>=0.3.75, but you have langchain-core 0.2.43 which is incompatible.
# langchain-chroma 1.1.0 requires langchain-core<2.0.0,>=1.1.3, but you have langchain-core 0.2.43 which is incompatible.
# Successfully installed numpy-1.26.4
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Found existing installation: scikit-surprise 1.1.4
# Uninstalling scikit-surprise-1.1.4:
#   Successfully uninstalled scikit-surprise-1.1.4
# Collecting scikit-surprise
#   Using cached scikit_surprise-1.1.4-cp312-cp312-macosx_11_0_arm64.whl
# Requirement already satisfied: joblib>=1.2.0 in /Users/surabhi/LLM/venv/lib/python3.12/site-packages (from scikit-surprise) (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /Users/surabhi/LLM/venv/lib/python3.12/site-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/surabhi/LLM/venv/lib/python3.12/site-packages (from scikit-surprise) (1.16.1)
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

ratings = pd.read_csv("../dataset/ratings.csv")

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1,5))
data = Dataset.load_from_df(ratings[['user_id','book_id','rating']], reader)
trainset ,testset = train_test_split(data, test_size=0.2)

# %%
from surprise import SVD
model = SVD(n_factors=100, n_epochs=20,random_state=42)
model.fit(trainset)

# %%
from surprise import accuracy
predictions = model.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8436
# 0.8436156477595279

# %%
import pickle
with open("../backend/models/svd_model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
import joblib

joblib.dump(model, "../backend/models/svd_model.pkl")
# Out:
# ['../backend/models/svd_model.pkl']
